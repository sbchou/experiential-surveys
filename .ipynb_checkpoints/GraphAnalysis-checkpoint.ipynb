# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
import inspect
from datetime import datetime
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
df = pandas.read_csv("Data/flattened.csv")

# %%
df.SOURCE.value_counts()[1:11].plot(kind='bar')
plt.title('Top Sources')

# %%
df.groupby('QKEY')['SOURCE'].value_counts()
# Out:
# QKEY          SOURCE
# 100446        .                               42
# 100588        .                               41
#               ESPN                             1
# 100598        .                               42
# 101493        .                               27
#               ABC                              3
#               Etrade                           1
#               Facebook                         1
#               Fox News                         1
#               Goldstar                         1
#               KAYAK                            1
#               KTLA? 5                          1
#               Money Map Press                  1
#               NBC                              1
#               Patriot-News                     1
#               The Motley Fool                  1
#               Thrillist                        1
#               VICE                             1
# 102009        .                               13
# ...

# %%
from itertools import islice, izip
test = list(df[df.QKEY == 201501796068].SOURCE)
pairs = izip(*[iter(test)]*2)

# %%
for p in pairs: print p
# Out:
# ('USA Today', 'Washington Post')
# ('New York Times', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', 'Blog.moz.com')
# ('.', '.')
# ('.', '.')
# ('.', '.')
# ('.', '.')

# %% [markdown]
# ## Let's do some network analysis

# %%
import networkx as nx

# %%
G=nx.DiGraph()
G.add_node("spam") 
G.add_edge("spam",2, weight=0.2) 
print(list(G.nodes()))

pos=nx.spring_layout(G) 
nx.draw(G,pos)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx(G,pos,edge_labels=labels)
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# [2, 'spam']
# {('spam', 2): <matplotlib.text.Text at 0x117c8e5d0>}

# %% [markdown]
# ## Build Graph

# %%
df_orig = pandas.read_csv("Data/NEWSSOURCE with standardized names.csv", index_col=0, dtype={'QKEY': str})

# %%
values = df_orig.values

# %%
values[0]
# Out:
# array(['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.',
#        '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.',
#        '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.',
#        '.', '.', '.'], dtype=object)

# %%
from itertools import izip

def pairwise(iterable):
    "s -> (s0, s1), (s2, s3), (s4, s5), ..."
    a = iter(iterable)
    return izip(a, a)


graph = {}
for ls in values:
    for p1,p2 in pairwise(ls):
        p1 = p1.decode('utf-8', 'ignore').encode('utf-8')
        if p1 not in graph.keys():
            graph[p1] = {}
        if p2 not in graph[p1].keys():
            graph[p1][p2] = {}
            graph[p1][p2]['weight'] = 1
        else:
            graph[p1][p2]['weight'] += 1

# %% [markdown]
# ## prune weight = 1

# %%
import copy
pruned = copy.deepcopy(graph)

# %%
for p1 in pruned.keys():
    for p2 in pruned[p1].keys():
        if pruned[p1][p2]['weight'] == 1:
            print p1, p2
            pruned[p1].pop(p2, None)
# Out:
# Bleacher Report BBC
# Bleacher Report ESPN
# Bleacher Report MovieWeb
# Politicus USA Salon Magazine
# Investopedia .
# ESPN Deadspin
# ESPN ESPN
# ESPN Huffington Post
# ESPN Slate
# ESPN The Daily Beast
# ESPN SB Nation
# ESPN Redskins radio
# ESPN Facebook
# ESPN Scores
# ESPN Patriots.com
# ESPN NBA
# ESPN NFL
# ESPN Yahoo!
# Direct Action Everywhere .
# Lawyers Guns & Money Blog FiveThirtyEight
# ABC 7 FOX 11
# ABC 7 Los Angeles Times
# KPLC oil city news
# Trumbull Times .
# The Daily Signal .
# 3Ders.org .
# The Oregonian Do not remember
# BeFrugal .
# Enoch Pratt Free Library .
# Local ABC affiliate New York Times
# Western Journalism Conservative Tribune
# Western Journalism .
# Western Journalism Fox News
# Western Journalism Franklin Graham
# Western Journalism Independent Journal Review
# Smithsonian .
# WBAL TV .
# Cleveland 19 News .
# Anti aging breakthrough Ex president of Mexico
# Oswego Renaissance .
# Patriot-News ABC
# FOX Sports ESPN
# KAKE CNN
# WEEI ESPN
# ...

# %%
for p1 in pruned.keys():
    for p2 in pruned[p1].keys():
        if p2 == {}:
            pruned[p1].pop(p2, None)

        
for p1 in pruned.keys():
    if pruned[p1].keys() == []:
        print p1
        pruned.pop(p1, None)
# Out:
# Politicus USA
# Investopedia
# Direct Action Everywhere
# Lawyers Guns & Money Blog
# ABC 7
# KPLC
# Trumbull Times
# The Daily Signal
# 3Ders.org
# The Oregonian
# BeFrugal
# Enoch Pratt Free Library
# Local ABC affiliate
# Western Journalism
# Smithsonian
# WBAL TV
# Cleveland 19 News
# Anti aging breakthrough
# Oswego Renaissance
# Patriot-News
# KAKE
# Mental Floss
# Courier?Post
# GQ
# Ola
# AFLCIO
# Marketplace
# WDBJ
# FOX 28 - WSJV
# Iowa Hawkeyes football
# Crain's Houston Business
# Channel 7 news
# RedState
# IrishCentral
# Fort Worth Star?Telegram
# Badass Teachers
# NBC Nightly News
# FOX 8 News
# HLN to Go
# WMUR
# Gizmodo
# imgur
# WSLS
# raspberrypi.org
# WGME?TV
# MLive
# Climate Home
# Hillary Clinton
# Ohio Rising
# ABC 36 WTVQ
# Hootsuite
# TuneIn
# Local government
# PolitiFact
# VoteTexas.gov
# KDRV
# Conservative News Outlet
# Tech insider
# McSweeny's
# Local 10 News
# Amazon
# Code.org
# Goldstar
# KDKA-TV
# guns
# Milwaukee Journal Sentinel
# Steezy
# ...

# %%
G=nx.from_dict_of_dicts(pruned)

# %%
pruned
# Out:
# {'.': {'.': {'weight': 39228},
#   '14 WFIE': {'weight': 2},
#   '6abc': {'weight': 3},
#   'ABC': {'weight': 15},
#   'ABC ': {'weight': 8},
#   'AJ+': {'weight': 3},
#   'AOL': {'weight': 6},
#   'AWM.com': {'weight': 3},
#   'Al Jazeera': {'weight': 2},
#   'Alaska Dispatch News': {'weight': 2},
#   "Alex Jones' Info Wars": {'weight': 2},
#   'Associated Press': {'weight': 5},
#   'BBC': {'weight': 12},
#   'Bernie Sanders': {'weight': 5},
#   'Blaze': {'weight': 2},
#   'Bleacher Report': {'weight': 17},
#   'Bloomberg': {'weight': 2},
#   'Breitbart': {'weight': 16},
#   'Brit + Co': {'weight': 2},
#   'BuzzFeed': {'weight': 7},
#   'CBS News': {'weight': 13},
#   'CBS Sports': {'weight': 5},
#   'CNBC': {'weight': 3},
#   'CNN': {'weight': 115},
#   'Carolina Hurricanes': {'weight': 2},
#   'Chicago Tribune': {'weight': 4},
#   'Daily Kos': {'weight': 8},
#   'Democratic National Committee': {'weight': 2},
#   'Detroit Free Press': {'weight': 2},
# ...

# %%
pos=nx.spring_layout(G) 
nx.draw(G,pos,node_size=60,font_size=8)  

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx(G,pos,edge_labels=labels, node_size=100, k=.9)

# %% [markdown]
# ## Repeat but drop nulls

# %%
df = pandas.read_csv("Data/NEWSSOURCE with standardized names.csv", index_col=0, dtype={'QKEY': str})

# %%
df = df.replace(['.'],[None])

# %%
values = df.values

# %%
big_array = []
for row in values:
    new_row = [v for v in row if v]
    if len(new_row) > 1:
        big_array.append(new_row)

# %%
len(big_array)
# Out:
# 824

# %%
for row in big_array:
    print len(row)
# Out:
# 15
# 29
# 3
# 3
# 9
# 2
# 8
# 3
# 20
# 12
# 15
# 2
# 2
# 3
# 4
# 8
# 3
# 4
# 2
# 6
# 2
# 8
# 13
# 2
# 2
# 11
# 5
# 2
# 3
# 2
# 3
# 3
# 5
# 12
# 3
# 3
# 8
# 2
# 12
# 2
# 22
# 12
# 5
# 2
# 3
# 15
# 9
# 2
# 3
# 4
# 9
# 6
# 3
# 2
# 6
# 3
# 7
# 3
# 6
# 9
# 18
# 2
# 2
# 25
# 21
# 14
# 7
# 4
# 2
# 13
# 30
# 2
# 9
# 7
# 19
# 10
# 4
# 6
# 4
# 9
# 6
# 3
# 2
# 2
# 7
# 10
# 5
# 4
# 3
# 2
# 4
# 5
# 5
# 9
# 3
# 2
# 3
# 11
# 10
# 2
# 12
# 8
# 4
# 18
# 6
# 2
# 6
# 10
# 4
# 9
# 5
# 4
# 6
# 4
# 6
# 9
# 10
# 2
# 5
# 19
# 10
# 7
# 2
# 2
# 5
# 5
# 3
# 2
# 2
# 3
# 3
# 11
# 3
# 4
# 17
# 2
# 6
# 7
# 3
# 4
# 4
# 6
# 16
# 8
# 2
# 9
# 9
# 10
# 3
# 6
# 3
# 2
# 13
# 27
# 3
# 7
# 14
# 3
# 3
# 5
# 15
# 9
# 3
# 3
# 7
# 2
# 11
# 9
# 7
# 11
# 5
# 3
# 7
# 8
# 17
# 12
# 11
# 9
# 15
# 3
# 9
# 4
# 3
# 5
# 8
# 4
# 6
# 5
# 3
# 2
# 8
# 3
# 23
# 6
# 10
# 2
# 9
# 2
# 8
# 3
# 4
# 7
# 6
# 2
# 5
# 34
# 23
# 6
# 5
# 19
# 11
# 19
# 11
# 5
# 18
# 5
# 8
# 5
# 2
# 2
# 29
# 2
# 2
# 33
# 3
# 15
# 4
# 6
# 22
# 2
# 2
# 3
# 5
# 3
# 2
# ...

# %%
from itertools import izip

def pairwise(iterable):
    "s -> (s0, s1), (s2, s3), (s4, s5), ..."
    a = iter(iterable)
    return izip(a, a)


graph = {}
for ls in big_array:
    for p1,p2 in pairwise(ls):
        p1 = p1.decode('utf-8', 'ignore').encode('utf-8')
        if p1 not in graph.keys():
            graph[p1] = {}
        if p2 not in graph[p1].keys():
            graph[p1][p2] = {}
            graph[p1][p2]['weight'] = 1
        else:
            graph[p1][p2]['weight'] += 1

# %%
graph
# Out:
# {'107.9 The River': {'oil city news': {'weight': 1}},
#  '13abc WTVG TV': {'NBC 24 WNWO': {'weight': 1}},
#  '270towin.com': {'The Hill': {'weight': 1}},
#  '2WBS': {'BBC': {'weight': 1}},
#  '30s Jazz': {'30s Jazz': {'weight': 1}},
#  '6abc': {'6abc': {'weight': 2}, 'ABC ': {'weight': 1}},
#  '99th': {'news': {'weight': 1}},
#  '9NEWS Denver': {'9NEWS Denver': {'weight': 1}},
#  'A blog': {'Breitbart': {'weight': 1}},
#  'ABC': {'ABC': {'weight': 1},
#   'ABC13 News': {'weight': 1},
#   'Blaze': {'weight': 1},
#   'Bloomberg': {'weight': 1},
#   'CBS News': {'weight': 1},
#   'CNN': {'weight': 4},
#   'Charlotte Observer': {'weight': 1},
#   'E!': {'weight': 1},
#   'FiveThirtyEight': {'weight': 2},
#   'Fox News': {'weight': 4},
#   'Google': {'weight': 1},
#   'Huffington Post': {'weight': 1},
#   'MSNBC': {'weight': 1},
#   'Mediaite': {'weight': 1},
#   'NBC': {'weight': 2},
#   'Politico': {'weight': 1},
#   'WND': {'weight': 1},
#   'billoreilly.com': {'weight': 1}},
# ...

# %% [markdown]
# ## prune weight = 1

# %%
import copy
pruned = copy.deepcopy(graph)

# %%
for p1 in pruned.keys():
    for p2 in pruned[p1].keys():
        if pruned[p1][p2]['weight'] == 1:
            print p1, p2
            pruned[p1].pop(p2, None)
# Out:
# Bleacher Report ESPN
# Bleacher Report Last Week Tonight with John Oliver
# Bleacher Report Detroit Red Wings
# Bleacher Report BBC
# Bleacher Report 9GAG
# Bleacher Report Chicago Tribune
# Bleacher Report KTLA? 5
# Bleacher Report MovieWeb
# ESPN Big Ten
# ESPN Huffington Post
# ESPN The Daily Beast
# ESPN SB Nation
# ESPN HLNtv
# ESPN MSNBC
# ESPN NHL
# ESPN Slate
# ESPN Breitbart
# ESPN FOX 11
# ESPN NBA
# ESPN Blackhawks App
# ESPN about sports
# ESPN WEEI
# ESPN CBS Sports
# ESPN Access Hollywood
# ESPN Redskins radio
# ESPN Patriots.com
# ESPN KTLA? 5
# ESPN Deadspin
# ABC 7 Facebook
# ABC 7 Los Angeles Times
# Law360 FOX Sports
# WGME?TV WGME?TV
# Trumbull Times People
# Today New York Times
# The Oregonian Do not remember
# BeFrugal SMS hospital
# NutritionFacts Local TV News
# NutritionFacts Yahoo!
# Local ABC affiliate New York Times
# Detroit Lions NFL
# Smithsonian Smithsonian
# The Western News TheBlaze
# Anti aging breakthrough Ex president of Mexico
# ...

# %%
for p1 in pruned.keys():
    for p2 in pruned[p1].keys():
        if p2 == {}:
            pruned[p1].pop(p2, None)

        
for p1 in pruned.keys():
    if pruned[p1].keys() == []:
        print p1
        pruned.pop(p1, None)
# Out:
# ABC 7
# Law360
# WGME?TV
# Trumbull Times
# Today
# The Oregonian
# BeFrugal
# NutritionFacts
# Local ABC affiliate
# Detroit Lions
# Smithsonian
# The Western News
# Anti aging breakthrough
# Patriot-News
# Elite Daily
# FOX Sports
# WEEI
# Mental Floss
# GQ
# Ola
# AFLCIO
# Marketplace
# Pitchfork
# FOX 28 - WSJV
# Crain's Houston Business
# Crains Houston Business
# KY3
# University of Arizona Athletics
# RedState
# SoBoNews
# NorthWest Florida Daily News
# Badass Teachers
# beIN SPORTS
# NBC Nightly News
# FOX 8 News
# HLN to Go
# Tom + Lorenzo
# WDIV?TV
# Pastor-e-mail
# Stephen Colbert
# imgur
# SNY
# News Republic
# MLive
# Hickory Daily Record
# Ohio Rising
# ABC 36 WTVQ
# Bat with integrated sensora
# BET
# PolitiFact
# 107.9 The River
# National Multiple Sclerosis Society
# SmartNews
# Conservative News Outlet
# Tech insider
# Local 10 News
# WhatsApp
# Rush
# Milwaukee Journal Sentinel
# Salon Magazine
# Christ plus
# Sporting News
# American Idol
# FOX WITI
# KTLA? 5
# ...

# %%
G=nx.from_dict_of_dicts(pruned)

# %%
pruned
# Out:
# {'6abc': {'6abc': {'weight': 2}},
#  'ABC': {'CNN': {'weight': 4},
#   'FiveThirtyEight': {'weight': 2},
#   'Fox News': {'weight': 4},
#   'NBC': {'weight': 2}},
#  'ABC ': {'ABC ': {'weight': 2},
#   'CNN': {'weight': 2},
#   'Fox News': {'weight': 2},
#   'Washington Post': {'weight': 2}},
#  'AJ+': {'Al Jazeera': {'weight': 2}, 'Truck News': {'weight': 3}},
#  'AOL': {'AOL': {'weight': 2}, 'Facebook': {'weight': 2}},
#  'AWM.com': {'Rush Limbaugh': {'weight': 2}},
#  'Al Jazeera': {'AJ+': {'weight': 3}, 'Al Jazeera': {'weight': 2}},
#  'Alaska Dispatch News': {'MSNBC': {'weight': 2}},
#  "Alex Jones' Info Wars": {'Drudge Report': {'weight': 2}},
#  'Associated Press': {'Alaska Dispatch News': {'weight': 2}},
#  'BBC': {'NPR': {'weight': 2}, 'Yahoo!': {'weight': 2}},
#  'Blaze': {'Drudge Report': {'weight': 3}},
#  'Bleacher Report': {'Bleacher Report': {'weight': 6},
#   'New York Times': {'weight': 2}},
#  'Bloomberg': {'New York Times': {'weight': 3},
# ...

# %%
print nx.info(G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 149
# Number of edges: 246
# Average degree:   3.3020

# %%
pos=nx.spring_layout(G) 
nx.draw(G,pos,node_size=60,font_size=8, k=1)  

labels = nx.get_edge_attributes(G,'weight')
#nx.draw_networkx(G,pos,edge_labels=labels, node_size=100)

# %% [markdown]
# ## connected comps

# %%
nx.is_connected(G)
# Out:
# False

# %%
subs = [s for s in nx.connected_component_subgraphs(G)]

# %%
len(subs)
# Out:
# 23

# %%
nx.draw(subs[0])

# %% [markdown]
#  ## convert to graph-tool

# %%
import graph_tool as gt



def get_prop_type(value, key=None):
    """
    Performs typing and value conversion for the graph_tool PropertyMap class.
    If a key is provided, it also ensures the key is in a format that can be
    used with the PropertyMap. Returns a tuple, (type name, value, key)
    """
    if isinstance(key, unicode):
        # Encode the key as ASCII
        key = key.encode('ascii', errors='replace')

    # Deal with the value
    if isinstance(value, bool):
        tname = 'bool'

    elif isinstance(value, int):
        tname = 'float'
        value = int(value)

    elif isinstance(value, float):
        tname = 'float'

    elif isinstance(value, unicode):
        tname = 'string'
        value = value.encode('ascii', errors='replace')

    elif isinstance(value, dict):
        tname = 'object'

    else:
        tname = 'string'
        value = str(value)

    return tname, value, key


def nx2gt(nxG):
    """
    Converts a networkx graph to a graph-tool graph.
    """
    # Phase 0: Create a directed or undirected graph-tool Graph
    gtG = gt.Graph(directed=nxG.is_directed())

    # Add the Graph properties as "internal properties"
    for key, value in nxG.graph.items():
        # Convert the value and key into a type for graph-tool
        tname, value, key = get_prop_type(value, key)

        prop = gtG.new_graph_property(tname) # Create the PropertyMap
        gtG.graph_properties[key] = prop     # Set the PropertyMap
        gtG.graph_properties[key] = value    # Set the actual value

    # Phase 1: Add the vertex and edge property maps
    # Go through all nodes and edges and add seen properties
    # Add the node properties first
    nprops = set() # cache keys to only add properties once
    for node, data in nxG.nodes_iter(data=True):

        # Go through all the properties if not seen and add them.
        for key, val in data.items():
            if key in nprops: continue # Skip properties already added

            # Convert the value and key into a type for graph-tool
            tname, _, key  = get_prop_type(val, key)

            prop = gtG.new_vertex_property(tname) # Create the PropertyMap
            gtG.vertex_properties[key] = prop     # Set the PropertyMap

            # Add the key to the already seen properties
            nprops.add(key)

    # Also add the node id: in NetworkX a node can be any hashable type, but
    # in graph-tool node are defined as indices. So we capture any strings
    # in a special PropertyMap called 'id' -- modify as needed!
    gtG.vertex_properties['id'] = gtG.new_vertex_property('string')

    # Add the edge properties second
    eprops = set() # cache keys to only add properties once
    for src, dst, data in nxG.edges_iter(data=True):

        # Go through all the edge properties if not seen and add them.
        for key, val in data.items():
            if key in eprops: continue # Skip properties already added

            # Convert the value and key into a type for graph-tool
            tname, _, key = get_prop_type(val, key)

            prop = gtG.new_edge_property(tname) # Create the PropertyMap
            gtG.edge_properties[key] = prop     # Set the PropertyMap

            # Add the key to the already seen properties
            eprops.add(key)

    # Phase 2: Actually add all the nodes and vertices with their properties
    # Add the nodes
    vertices = {} # vertex mapping for tracking edges later
    for node, data in nxG.nodes_iter(data=True):

        # Create the vertex and annotate for our edges later
        v = gtG.add_vertex()
        vertices[node] = v

        # Set the vertex properties, not forgetting the id property
        data['id'] = str(node)
        for key, value in data.items():
            gtG.vp[key][v] = value # vp is short for vertex_properties

    # Add the edges
    for src, dst, data in nxG.edges_iter(data=True):

        # Look up the vertex structs from our vertices mapping and add edge.
        e = gtG.add_edge(vertices[src], vertices[dst])

        # Add the edge properties
        for key, value in data.items():
            gtG.ep[key][e] = value # ep is short for edge_properties

    # Done, finally!
    return gtG

# %%
gtG = nx2gt(G)

# %%
gtG
# Out:
# <Graph object, undirected, with 245 vertices and 345 edges at 0x129b3e450>

# %%
from graph_tool.all import graph_draw,Graph

# %%
graph_draw(gtG,output_size=(1000,1000))
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x129b3e450, at 0x11780aed0>

# %%
gtG.edge_properties["weight"]
# Out:
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x129b3e450, at 0x129b3e910>

# %%
 graph_draw(gtG, edge_text=gtG.edge_properties["weight"])
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x129b3e450, at 0x129b24c50>
